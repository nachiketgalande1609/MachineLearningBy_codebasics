# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(0, 5, 250)

# %%
plt.hist(x, 5)
plt.show()

# %%
y = np.random.normal(5, 1, 250)

# %%
plt.hist(y, 100)
plt.show()

# %%
plt.scatter(x, y)
plt.show()
